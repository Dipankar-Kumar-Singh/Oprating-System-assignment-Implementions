# %%
import pandas as pd 
import numpy as nd 
from sklearn.model_selection import train_test_split 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("temperatures.csv")

# %%
# plt.figure(figsize= (16,9))
plt.title("temperatures of INDIA")
plt.xlabel("YEAR")
plt.ylabel("AVG ANUAL TEMP")
plt.scatter(df[['YEAR']] , df['ANNUAL'])

# %%
x_train, x_test , y_train , y_test = train_test_split(df[['YEAR']] , df['ANNUAL'])

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred , color = 'orange')

# %%
print(reg.predict([[2200]]))
# Out:
# [32.40786008]
# /home/dk/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.20133596397578893
